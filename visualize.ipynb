# %%
from main import main
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#set variables
numStudents = 75
courses = ["Discrete Math","Operations Research","Real Analysis","Number Theory",
           "Algebraic Structures","Graph Theory","Cryptography","Multivariate Analysis",
           "Matrix Theory","Differential Equations","Numerical Methods","Combinatorics",
           "Discrete Time Finance","Concepts of Mathematics","Basic Logic","Probability"]
minEnrollment = 3
maxEnrollment = 6
timeSlots = ["11","12","13","21","22","23","31","32","33","41","42","43"]
size = 15
generation = 500

# %%
#get evolution of performance
history = main(numStudents,courses,minEnrollment,
                     maxEnrollment,timeSlots,size,generation)

# %%
history_df = pd.Series(history)
history_df.tail()
# Out:
# 495    78055.0
# 496    85005.0
# 497    96875.0
# 498    99435.0
# 499    98155.0
# dtype: float64

# %%
plt.plot(history_df)
plt.show()
